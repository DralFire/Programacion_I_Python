# %% [markdown]
# <h1>Homework 14</h1>
#
# <h5>PÉREZ ROSAS LUIS ALFREDO | MCD | UDG | 2025-2 | Grupo 2</h5>
#
# 1. Utilizar un script de los que han hecho de tarea, hacerle al menos dos modificaciones, guardando los cambios en el repositorio local de git.
# 2. Crear un sitio de Github
# 3. Subir a Github todas las versiones del archivo que modificaron.
#
# Subir capturas de pantallas como evidencias así como el enlace al sitio público.

# %% [markdown]
# ## <i> Filtrando información desde una interfaz gráfica
#
# 1. Crear una aplicación en la que lleven a cabo filtros de al menos dos variables

# %%
import pyodbc
import pandas as pd
import tkinter as tk

from tkinter import *
from tkinter import ttk #Importamos todas las funciones que contiene tkinter
from tkinter.ttk import *
from tkinter import messagebox

server = 'localhost'
bd = 'db_mysql'
usuario = 'root'
password = 'abc123'

class General:
	def __init__(self, raiz):
		self.genero = StringVar()
		self.label_genero = Label(raiz, text = "Gender")
		self.label_genero.grid(column=0, row=0)
		self.genero = Combobox(raiz, values=('W', 'M'), width=5)
		self.genero.grid(column=0, row=1)

		self.estado = StringVar()
		self.label_estado = Label(raiz, text = "Country")
		self.label_estado.grid(column=0, row=5)
		
        #Creamos el combobox para seleccionar el estado, CAMBIO: Se delimita a 3 países ***
		self.estado = Combobox(raiz, values=(           
            "CHL",            
            "COL",            
            "MEX"
			)
        , width=10)
		self.estado.grid(column=0,row=6)

		#Creamos los botones
		#Con command le decimos cual función queremos que lleve a cabo
		self.boton_buscar= Button(raiz, text="Search", command=self.buscar)
		self.boton_buscar.grid(column=0, row=20)

		self.boton_borrar=Button(raiz, text="Clean", command=self.borrar)
		self.boton_borrar.grid(column=0, row=30)

		#Tabla
		self.tabla=ttk.Treeview(raiz, column=("c1", "c2", "c3"), show='headings', height=8)
		self.tabla.column("# 1",anchor=CENTER, stretch=NO, width=100)
		self.tabla.heading("# 1", text="Name")
		self.tabla.column("# 2", anchor=CENTER, stretch=NO)
		self.tabla.heading("# 2", text="Gender")
		#self.tabla.column("# 3", anchor=CENTER, stretch=NO)
		#self.tabla.heading("# 3", text="Estado Civil")
		self.tabla.grid(column=0, row=40)

	def buscar(self):        
        
		genero_valor = "'" + self.genero.get() + "'"
		print(genero_valor)

		estado = "'" + self.estado.get() + "'"
		print(estado)

		try:
				conexion = pyodbc.connect(driver='{MySQL ODBC 9.4 Unicode Driver}', SERVER = server, DATABASE = bd,UID=usuario,PWD=password, PORT=3306)
				print('Conexión exitosa')
		except:
				print('La conexión no fué exitosa')

		#Creamos un cursor para almacenar la información en memoria
		cursor = conexion.cursor()

		cursor.execute("SELECT Year, Race, Name, Gender, Age, State, Country, Overall, Finish FROM maratonny_python3 WHERE Gender= " + genero_valor + "AND Country = " + estado)

		datos_clientes = cursor.fetchall()
		print(datos_clientes)
		conexion.commit()

		#Nos aseguramos de cerrar la conexión
		conexion.close()
        
		messagebox.showinfo("Results", datos_clientes)

	#def desplegar_resultados(self):

	def borrar(self):
		self.genero.set("")
		self.estado.set("")





#Creamos el objeto que será la raiz de la aplicación
raiz = Tk()
#Le agregamos un título | CAMBIO: Se modifica el título ***
raiz.title("Search My Score in GO Marathon")
#Determinamos si se podrá cambiar su tamaño
raiz.resizable(1,1)
#Asignamos un logotipo | CAMBIO: Se modifica el ícono ***
raiz.iconbitmap('estacion-oro-gasolinera-tijuana.ico')
#Asignamos un tipo de cursor, un color de background y un borde a la raiz
raiz.config(bd=8)
raiz.config(relief="ridge")
estructura = General(raiz)

raiz.mainloop()
# Out:
# 'M'
# 'COL'
# Conexión exitosa
# [(2024, 'NYC Marathon', 'Oscar Acosta', 'M', 36, 'BOGOTÁ', 'COL', 39, '8523'), (2024, 'NYC Marathon', 'Leonardo Sanabria Ortiz', 'M', 42, 'BOGOTÁ', 'COL', 133, '9024'), (2024, 'NYC Marathon', 'Camilo Aramburo', 'M', 41, 'ANTIOQUIA', 'COL', 1110, '10267'), (2024, 'NYC Marathon', 'Javier Enrique Garcia Romero', 'M', 55, 'BOGOTÁ', 'COL', 1132, '10281'), (2024, 'NYC Marathon', 'Leonardo Sanabria', 'M', 54, 'CUNDINAMARCA', 'COL', 1145, '10288'), (2024, 'NYC Marathon', 'Hugo Morales', 'M', 41, 'ATLÁNTICO', 'COL', 1216, '10348'), (2024, 'NYC Marathon', 'Álvaro Andrés Maya', 'M', 40, 'COLOMBIA', 'COL', 1701, '10626'), (2024, 'NYC Marathon', 'Juan Venegas', 'M', 48, 'COLOMBIA', 'COL', 2021, '10742'), (2024, 'NYC Marathon', 'Carlos Andres Guataqui Caballero', 'M', 33, 'BOGOTÁ', 'COL', 2140, '10782'), (2024, 'NYC Marathon', 'Jhon Pinilla', 'M', 34, 'BOGOTÁ', 'COL', 2219, '10812'), (2024, 'NYC Marathon', 'Hector Dario Castiblanco Caicedo', 'M', 40, 'CUNDINAMARCA', 'COL', 2279, '10842'), (2024, 'NYC Marathon', 'Ricardo Pedroza', 'M', 40, 'BOGOTÁ', 'COL', 2322, '10865'), (2024, 'NYC Marathon', 'Victor Hugo Pacheco Jacome', 'M', 39, 'ANTIOQUIA', 'COL', 2429, '10936'), (2024, 'NYC Marathon', 'Manuel Contreras', 'M', 33, 'BOGOTA', 'COL', 2448, '10944'), (2024, 'NYC Marathon', 'John Rios', 'M', 47, 'BOGOTA', 'COL', 2740, '11098'), (2024, 'NYC Marathon', 'Andres Corrales', 'M', 44, 'ANTIOQUIA', 'COL', 2772, '11114'), (2024, 'NYC Marathon', 'Diego Leon', 'M', 41, 'ANTIOQUIA', 'COL', 2932, '11191'), (2024, 'NYC Marathon', 'Jose Libardo Pulido Rios', 'M', 40, 'BOGOTÁ', 'COL', 3042, '11238'), (2024, 'NYC Marathon', 'Juan Henao', 'M', 43, 'ANTIOQUIA', 'COL', 3314, '11353'), (2024, 'NYC Marathon', 'Eduardo Acevedo', 'M', 37, 'CUNDINAMARCA', 'COL', 3366, '11377'), (2024, 'NYC Marathon', 'Omar Eduardo Rodriguez', 'M', 54, 'BOGOTA', 'COL', 3484, '11435'), (2024, 'NYC Marathon', 'Daniel Martinez Cardenas', 'M', 37, 'BOGOTÁ', 'COL', 3601, '11482'), (2024, 'NYC Marathon', 'Oscar Javier Siza Moreno', 'M', 44, 'CUNDINAMARCA', 'COL', 3891, '11595'), (2024, 'NYC Marathon', 'Antonio Brieva', 'M', 40, 'ANTIOQUIA', 'COL', 4386, '11768'), (2024, 'NYC Marathon', 'Gustavo A Diaz Tabares', 'M', 44, 'CUNDINANARCA', 'COL', 4467, '11791'), (2024, 'NYC Marathon', 'Jorge Andrés Mora', 'M', 40, 'ANTIOQUIA', 'COL', 4644, '11849'), (2024, 'NYC Marathon', 'Andres Felipe Sierra Agudelo', 'M', 39, 'ANTIOQUIA', 'COL', 5236, '12020'), (2024, 'NYC Marathon', 'Diego Ortega', 'M', 40, 'ANTIOQUIA', 'COL', 6384, '12318'), (2024, 'NYC Marathon', 'Alejandro Alcalá', 'M', 50, 'CUNDINAMARCA / COLOMBIA', 'COL', 6647, '12379'), (2024, 'NYC Marathon', 'Gabriel Ortega', 'M', 34, 'BOGOTA', 'COL', 7183, '12497'), (2024, 'NYC Marathon', 'German Andres Perez Cortes', 'M', 39, 'BOGOTÁ', 'COL', 7461, '12548'), (2024, 'NYC Marathon', 'Carlos Andraus Quintero', 'M', 42, 'ATLANTICO', 'COL', 7593, '12570'), (2024, 'NYC Marathon', 'Jorge Cano', 'M', 33, 'ANTIOQUIA', 'COL', 7628, '12575'), (2024, 'NYC Marathon', 'German Centeno', 'M', 52, 'CUNDINMARCA', 'COL', 7676, '12584'), (2024, 'NYC Marathon', 'Alfonso Gomez', 'M', 55, 'DC', 'COL', 7678, '12584'), (2024, 'NYC Marathon', 'Fabian Andres Hernandez', 'M', 53, 'BOGOTÁ', 'COL', 7680, '12584'), (2024, 'NYC Marathon', 'Jeronimo Upegui', 'M', 35, 'ANTIOQUIA', 'COL', 7697, '12588'), (2024, 'NYC Marathon', 'Jose Manuel Ordonez', 'M', 42, 'BOGOTA', 'COL', 8072, '12676'), (2024, 'NYC Marathon', 'Carlos Garces', 'M', 51, 'BOGOTÁ', 'COL', 8227, '12712'), (2024, 'NYC Marathon', 'Juan Carlos Hernandez', 'M', 58, 'BOGOTÁ', 'COL', 8236, '12714'), (2024, 'NYC Marathon', 'Alejandro Uribe Ortiz', 'M', 40, 'CUNDINAMARCA', 'COL', 8338, '12734'), (2024, 'NYC Marathon', 'Mario Puerta', 'M', 43, 'BOGOTÁ', 'COL', 8460, '12762'), (2024, 'NYC Marathon', 'David Alba', 'M', 41, 'CUNDINAMARCA', 'COL', 8717, '12817'), (2024, 'NYC Marathon', 'Jorge Andres Hurtado Uribe', 'M', 50, 'ANTIOQUIA', 'COL', 9011, '12883'), (2024, 'NYC Marathon', 'Daniel Eduardo Montoya Torres', 'M', 27, 'BOGO ...
# 'M'
# 'COL'
# Conexión exitosa
# [(2024, 'NYC Marathon', 'Oscar Acosta', 'M', 36, 'BOGOTÁ', 'COL', 39, '8523'), (2024, 'NYC Marathon', 'Leonardo Sanabria Ortiz', 'M', 42, 'BOGOTÁ', 'COL', 133, '9024'), (2024, 'NYC Marathon', 'Camilo Aramburo', 'M', 41, 'ANTIOQUIA', 'COL', 1110, '10267'), (2024, 'NYC Marathon', 'Javier Enrique Garcia Romero', 'M', 55, 'BOGOTÁ', 'COL', 1132, '10281'), (2024, 'NYC Marathon', 'Leonardo Sanabria', 'M', 54, 'CUNDINAMARCA', 'COL', 1145, '10288'), (2024, 'NYC Marathon', 'Hugo Morales', 'M', 41, 'ATLÁNTICO', 'COL', 1216, '10348'), (2024, 'NYC Marathon', 'Álvaro Andrés Maya', 'M', 40, 'COLOMBIA', 'COL', 1701, '10626'), (2024, 'NYC Marathon', 'Juan Venegas', 'M', 48, 'COLOMBIA', 'COL', 2021, '10742'), (2024, 'NYC Marathon', 'Carlos Andres Guataqui Caballero', 'M', 33, 'BOGOTÁ', 'COL', 2140, '10782'), (2024, 'NYC Marathon', 'Jhon Pinilla', 'M', 34, 'BOGOTÁ', 'COL', 2219, '10812'), (2024, 'NYC Marathon', 'Hector Dario Castiblanco Caicedo', 'M', 40, 'CUNDINAMARCA', 'COL', 2279, '10842'), (2024, 'NYC Marathon', 'Ricardo Pedroza', 'M', 40, 'BOGOTÁ', 'COL', 2322, '10865'), (2024, 'NYC Marathon', 'Victor Hugo Pacheco Jacome', 'M', 39, 'ANTIOQUIA', 'COL', 2429, '10936'), (2024, 'NYC Marathon', 'Manuel Contreras', 'M', 33, 'BOGOTA', 'COL', 2448, '10944'), (2024, 'NYC Marathon', 'John Rios', 'M', 47, 'BOGOTA', 'COL', 2740, '11098'), (2024, 'NYC Marathon', 'Andres Corrales', 'M', 44, 'ANTIOQUIA', 'COL', 2772, '11114'), (2024, 'NYC Marathon', 'Diego Leon', 'M', 41, 'ANTIOQUIA', 'COL', 2932, '11191'), (2024, 'NYC Marathon', 'Jose Libardo Pulido Rios', 'M', 40, 'BOGOTÁ', 'COL', 3042, '11238'), (2024, 'NYC Marathon', 'Juan Henao', 'M', 43, 'ANTIOQUIA', 'COL', 3314, '11353'), (2024, 'NYC Marathon', 'Eduardo Acevedo', 'M', 37, 'CUNDINAMARCA', 'COL', 3366, '11377'), (2024, 'NYC Marathon', 'Omar Eduardo Rodriguez', 'M', 54, 'BOGOTA', 'COL', 3484, '11435'), (2024, 'NYC Marathon', 'Daniel Martinez Cardenas', 'M', 37, 'BOGOTÁ', 'COL', 3601, '11482'), (2024, 'NYC Marathon', 'Oscar Javier Siza Moreno', 'M', 44, 'CUNDINAMARCA', 'COL', 3891, '11595'), (2024, 'NYC Marathon', 'Antonio Brieva', 'M', 40, 'ANTIOQUIA', 'COL', 4386, '11768'), (2024, 'NYC Marathon', 'Gustavo A Diaz Tabares', 'M', 44, 'CUNDINANARCA', 'COL', 4467, '11791'), (2024, 'NYC Marathon', 'Jorge Andrés Mora', 'M', 40, 'ANTIOQUIA', 'COL', 4644, '11849'), (2024, 'NYC Marathon', 'Andres Felipe Sierra Agudelo', 'M', 39, 'ANTIOQUIA', 'COL', 5236, '12020'), (2024, 'NYC Marathon', 'Diego Ortega', 'M', 40, 'ANTIOQUIA', 'COL', 6384, '12318'), (2024, 'NYC Marathon', 'Alejandro Alcalá', 'M', 50, 'CUNDINAMARCA / COLOMBIA', 'COL', 6647, '12379'), (2024, 'NYC Marathon', 'Gabriel Ortega', 'M', 34, 'BOGOTA', 'COL', 7183, '12497'), (2024, 'NYC Marathon', 'German Andres Perez Cortes', 'M', 39, 'BOGOTÁ', 'COL', 7461, '12548'), (2024, 'NYC Marathon', 'Carlos Andraus Quintero', 'M', 42, 'ATLANTICO', 'COL', 7593, '12570'), (2024, 'NYC Marathon', 'Jorge Cano', 'M', 33, 'ANTIOQUIA', 'COL', 7628, '12575'), (2024, 'NYC Marathon', 'German Centeno', 'M', 52, 'CUNDINMARCA', 'COL', 7676, '12584'), (2024, 'NYC Marathon', 'Alfonso Gomez', 'M', 55, 'DC', 'COL', 7678, '12584'), (2024, 'NYC Marathon', 'Fabian Andres Hernandez', 'M', 53, 'BOGOTÁ', 'COL', 7680, '12584'), (2024, 'NYC Marathon', 'Jeronimo Upegui', 'M', 35, 'ANTIOQUIA', 'COL', 7697, '12588'), (2024, 'NYC Marathon', 'Jose Manuel Ordonez', 'M', 42, 'BOGOTA', 'COL', 8072, '12676'), (2024, 'NYC Marathon', 'Carlos Garces', 'M', 51, 'BOGOTÁ', 'COL', 8227, '12712'), (2024, 'NYC Marathon', 'Juan Carlos Hernandez', 'M', 58, 'BOGOTÁ', 'COL', 8236, '12714'), (2024, 'NYC Marathon', 'Alejandro Uribe Ortiz', 'M', 40, 'CUNDINAMARCA', 'COL', 8338, '12734'), (2024, 'NYC Marathon', 'Mario Puerta', 'M', 43, 'BOGOTÁ', 'COL', 8460, '12762'), (2024, 'NYC Marathon', 'David Alba', 'M', 41, 'CUNDINAMARCA', 'COL', 8717, '12817'), (2024, 'NYC Marathon', 'Jorge Andres Hurtado Uribe', 'M', 50, 'ANTIOQUIA', 'COL', 9011, '12883'), (2024, 'NYC Marathon', 'Daniel Eduardo Montoya Torres', 'M', 27, 'BOGO ...

# %% [markdown]
# ### Muestra de la Interfaz

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### 1. Utilizar un script de los que han hecho de tarea, hacerle al menos dos modificaciones, guardando los cambios en el repositorio local de git. <br> EVIDENCIA DE CAMBIOS EN REPOSITORIO LOCAL

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### 2. Crear un sitio de Github EVIDENCIA DE CAMBIOS EN REPOSITORIO EN GITHUB

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### 3. Subir a Github todas las versiones del archivo que modificaron.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
